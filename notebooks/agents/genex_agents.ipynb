# %% [markdown]
# # Genex Core Agents — Profile Memory + Research + Therapy Planning (ADK Notebook)
#
# ## What this notebook is
# This notebook is the **core Genex agent prototype** built with **Google ADK (Agent Development Kit)**. It demonstrates how **persistent child context** (profile memory) can be shared across **multiple agent types**—research, planning, and summarization—within a single conversational session.
#
# Think of this file as the **foundation layer** from which the more specialized Genex notebooks (therapy planners, Q&A pipelines, research-only agents) are derived.
#
# > This is an educational prototype and **not a medical system**.
#
# ---
#
# ## Inputs (what you must provide)
# ### 1) API keys
# Depending on which agents are enabled, this notebook may initialize:
# - `OPENAI_API_KEY` (GPT)
# - `GOOGLE_API_KEY` (Gemini)
# - `ANTHROPIC_API_KEY` (Claude)
#
# Keys are loaded via `python-dotenv`.
#
# ### 2) Parent prompts (runtime)
# You interact with the system through:
# - an initial message containing **child name, age, diagnosis**
# - follow-up messages requesting research, activities, or plans
#
# All interactions must use the same `user_id` and `session_id` to preserve context.
#
# ---
#
# ## What it does (process overview)
# ### A) Child profile memory (shared state)
# - A **Profile Agent** extracts and stores child metadata in ADK session state.
# - A retrieval tool ensures downstream agents can safely access the profile before responding.
#
# This enables:
# - “Tell me more activities” without repeating the child’s info
# - Cross-agent continuity in the same session
#
# ### B) Modular agents (composable)
# This notebook defines and wires together multiple agent roles, typically including:
# - **Research Agent** – therapy or intervention research based on diagnosis and age
# - **Planning Agent** – structured suggestions (e.g., daily activities or routines)
# - **Summary / Response Agent** – parent-friendly explanations and recap
#
# Agents may run sequentially or conditionally depending on the prompt.
#
# ### C) Single conversational runner
# A single ADK `Runner` orchestrates:
# - profile storage (if missing)
# - agent invocation
# - final response emission
#
# ---
#
# ## Outputs (what you get)
# ### Console output
# - Each call prints the final agent response (research, plan, or summary).
# - Intermediate tool calls can be viewed when using `run_debug()`.
#
# ### Session state (in-memory)
# Using `InMemorySessionService`, the notebook stores:
# - `child_profile`
# - optional intermediate artifacts (research notes, plan drafts, etc.)
#
# State persists only for the life of the kernel and the chosen session id.
#
# ---
#
# ## How to run
# 1) Run all cells top-to-bottom to register tools, agents, and the runner.
# 2) Start with a prompt that includes the child profile.
# 3) Continue the conversation with follow-up requests (research, activities, refinements).
#
# ---
#
# ## When to use this notebook
# - As a **reference architecture** for Genex agents
# - For experimentation with shared memory across agents
# - As a starting point for building new pipelines (therapy, education, care coordination)
#
# ## Limitations / known constraints
# - In-memory state only (no database persistence).
# - Behavior depends on enabled models and API access.
# - Not intended for diagnosis or clinical decision-making.

# %%
# Authentication
import os
from dotenv import load_dotenv

load_dotenv()  # loads .env from project root

os.environ["GOOGLE_GENAI_USE_VERTEXAI"] = "FALSE"

from openai import OpenAI
openai_client = OpenAI(api_key=os.getenv("OPENAI_API_KEY"))

from anthropic import Anthropic
anthropic_client = Anthropic(api_key=os.getenv("ANTHROPIC_API_KEY"))

print("All API clients initialized successfully.")
print("Google:", os.getenv("GOOGLE_API_KEY")[:5])
print("OpenAI:", os.getenv("OPENAI_API_KEY")[:5])
print("Anthropic:", os.getenv("ANTHROPIC_API_KEY")[:5])

# %%
# Imports
from google.adk.agents import Agent, LlmAgent, SequentialAgent, ParallelAgent
from google.adk.models.google_llm import Gemini
from google.adk.runners import InMemoryRunner, Runner
from google.adk.tools import FunctionTool, ToolContext
from google.adk.sessions import DatabaseSessionService
from google.adk.apps.app import App, EventsCompactionConfig
from google.genai import types
from openai import OpenAI
from anthropic import Anthropic
import uuid

from typing import Any, Dict

# %%
# Gemini test
test_agent = LlmAgent(
    name="test",
    model=Gemini(model="gemini-2.5-flash"),
    instruction="Say hi."
)
runner = InMemoryRunner(agent=test_agent)
await runner.run_debug("Hello")
# Out:
#  ### Created new session: debug_session_id
#
# User > Hello
# test > Hi! How can I help you today?
# [Event(model_version='gemini-2.5-flash', content=Content(
#    parts=[
#      Part(
#        text='Hi! How can I help you today?'
#      ),
#    ],
#    role='model'
#  ), grounding_metadata=None, partial=None, turn_complete=None, finish_reason=<FinishReason.STOP: 'STOP'>, error_code=None, error_message=None, interrupted=None, custom_metadata=None, usage_metadata=GenerateContentResponseUsageMetadata(
#    candidates_token_count=9,
#    prompt_token_count=19,
#    prompt_tokens_details=[
#      ModalityTokenCount(
#        modality=<MediaModality.TEXT: 'TEXT'>,
#        token_count=19
#      ),
#    ],
#    thoughts_token_count=16,
#    total_token_count=44
#  ), live_session_resumption_update=None, input_transcription=None, output_transcription=None, avg_logprobs=None, logprobs_result=None, cache_metadata=None, citation_metadata=None, invocation_id='e-965de6a4-a4c0-4917-b42d-271a082df5cc', author='test', actions=EventActions(skip_summarization=None, state_delta={}, artifact_delta={}, transfer_to_agent=None, escalate=None, requested_auth_configs={}, requested_tool_confirmations={}, compaction=None, end_of_agent=None, agent_state=None, rewind_before_invocation_id=None), long_running_tool_ids=None, branch=None, id='f0eab233-e54b-40be-be06-1def7f94b373', timestamp=1764357010.860663)]

# %%
# OpenAI test
openai_client.chat.completions.create(
    model="gpt-4o-mini",
    messages=[{"role":"user","content":"hi"}]
)
# Out:
# ChatCompletion(id='chatcmpl-Cgy97neHJwn66g9rA9WfhfO9d2Ruw', choices=[Choice(finish_reason='stop', index=0, logprobs=None, message=ChatCompletionMessage(content='Hello! How can I assist you today?', refusal=None, role='assistant', annotations=[], audio=None, function_call=None, tool_calls=None))], created=1764357013, model='gpt-4o-mini-2024-07-18', object='chat.completion', service_tier='default', system_fingerprint='fp_560af6e559', usage=CompletionUsage(completion_tokens=9, prompt_tokens=8, total_tokens=17, completion_tokens_details=CompletionTokensDetails(accepted_prediction_tokens=0, audio_tokens=0, reasoning_tokens=0, rejected_prediction_tokens=0), prompt_tokens_details=PromptTokensDetails(audio_tokens=0, cached_tokens=0)))

# %%
# Anthropic test
anthropic_client.messages.create(
    model="claude-3-5-haiku-20241022",
    max_tokens=10,
    messages=[{"role":"user","content":"hi"}]
)
# Out:
# Message(id='msg_017jLf6cb3S5DTAVQM9dYLGB', content=[TextBlock(citations=None, text='Hello! How are you doing today? Is there', type='text')], model='claude-3-5-haiku-20241022', role='assistant', stop_reason='max_tokens', stop_sequence=None, type='message', usage=Usage(cache_creation=CacheCreation(ephemeral_1h_input_tokens=0, ephemeral_5m_input_tokens=0), cache_creation_input_tokens=0, cache_read_input_tokens=0, input_tokens=8, output_tokens=10, server_tool_use=None, service_tier='standard'))

# %%
retry_config=types.HttpRetryOptions(
    attempts=5,  # Maximum retry attempts
    exp_base=7,  # Delay multiplier
    initial_delay=1, # Initial delay before first retry (in seconds)
    http_status_codes=[429, 500, 503, 504] # Retry on these HTTP errors
)

# %% [markdown]
# ### Helper Function Save and Retrieve Child's Profile

# %%
def save_child_profile(
    tool_context: ToolContext,
    name: str,
    age_years: int,
    diagnosis: str,
) -> Dict[str, Any]:
    """
    Store child profile (e.g., Emma, 3, Down syndrome) in session state.
    """
    tool_context.state["child:name"] = name
    tool_context.state["child:age_years"] = age_years
    tool_context.state["child:diagnosis"] = diagnosis

    return {"status": "success"}


def retrieve_child_profile(tool_context: ToolContext) -> Dict[str, Any]:
    """
    Retrieve child profile from session state.
    """
    name = tool_context.state.get("child:name")
    age_years = tool_context.state.get("child:age_years")
    diagnosis = tool_context.state.get("child:diagnosis")

    if name is None or age_years is None or diagnosis is None:
        return {
            "status": "error",
            "message": "No child profile found in this session.",
        }

    return {
        "status": "success",
        "name": name,
        "age_years": age_years,
        "diagnosis": diagnosis,
    }

# %% [markdown]
# ### GPT Research Tool

# %%
def gpt_child_research_tool(tool_context: ToolContext) -> dict:
    """
    Uses Emma's profile from session state to call GPT-4o-mini
    and get age- & diagnosis-specific therapy recommendations.
    """
    profile = retrieve_child_profile(tool_context)
    if profile["status"] != "success":
        return {
            "status": "error",
            "error_message": "No child profile found. Please provide name, age, and diagnosis first."
        }

    name = profile["name"]
    age = profile["age_years"]
    diagnosis = profile["diagnosis"]

    prompt = f"""
    You are a pediatric developmental specialist.

    Child profile:
    - Name: {name}
    - Age: {age} years
    - Diagnosis: {diagnosis}

    Task:
    1. Give a one-sentence summary of {diagnosis} in the context of a {age}-year-old child.
    2. Provide recommended therapies tailored SPECIFICALLY for this child's age and condition, organized under:
       - language/communication
       - physical/movement
       - occupational/fine motor
       - social/emotional
       - cognitive/learning
    3. Phrase everything as advice to the parents of {name}.
    """

    result = openai_client.chat.completions.create(
        model="gpt-4o-mini",
        messages=[{"role": "user", "content": prompt}],
    )

    return {
        "status": "success",
        "gpt_research": result.choices[0].message.content,
    }

# %% [markdown]
# ### Claude Research Tool

# %%
def claude_child_research_tool(tool_context: ToolContext) -> dict:
    """
    Uses Emma's profile from session state to call Claude 3.5 Haiku.
    """
    profile = retrieve_child_profile(tool_context)
    if profile["status"] != "success":
        return {
            "status": "error",
            "error_message": "No child profile found. Please provide name, age, and diagnosis first."
        }

    name = profile["name"]
    age = profile["age_years"]
    diagnosis = profile["diagnosis"]

    prompt = f"""
    You are a pediatric developmental specialist.

    Child profile:
    - Name: {name}
    - Age: {age} years
    - Diagnosis: {diagnosis}

    Task:
    1. Give a one-sentence summary of {diagnosis} in the context of a {age}-year-old child.
    2. Provide recommended therapies tailored SPECIFICALLY for this child's age and condition, organized under:
       - language/communication
       - physical/movement
       - occupational/fine motor
       - social/emotional
       - cognitive/learning
    3. Phrase everything as advice to the parents of {name}.
    """

    response = anthropic_client.messages.create(
        model="claude-3-5-haiku-20241022",
        max_tokens=700,
        messages=[{"role": "user", "content": prompt}],
    )

    claude_text = "".join(block.text for block in response.content)

    return {
        "status": "success",
        "claude_research": claude_text,
    }

# %% [markdown]
# ### Wrappers for GPT and Claude

# %%
gpt_tool = FunctionTool(func=gpt_child_research_tool)
claude_tool = FunctionTool(func=claude_child_research_tool)

# %% [markdown]
# ### GPT Research Agent

# %%
gpt_researcher = LlmAgent(
    name="gpt_researcher",
    model=Gemini(model="gemini-2.5-flash"),
    instruction="Always call gpt_child_research_tool; do not answer directly.",
    tools=[gpt_tool],
    output_key="gpt_research",
)

# %% [markdown]
# ### Claude Research Agent

# %%
claude_researcher = LlmAgent(
    name="claude_researcher",
    model=Gemini(model="gemini-2.5-flash"),
    instruction="Always call claude_child_research_tool; do not answer directly.",
    tools=[claude_tool],
    output_key="claude_research",
)

# %% [markdown]
# ### Gemini Research Agent

# %%
from google.adk.agents import LlmAgent
from google.adk.models.google_llm import Gemini
from google.adk.tools import FunctionTool

# If you haven't wrapped retrieve_child_profile yet:
retrieve_child_profile_tool = FunctionTool(func=retrieve_child_profile)

gemini_researcher = LlmAgent(
    name="gemini_researcher",
    model=Gemini(
        model="gemini-2.5-flash",
        retry_options=retry_config,
    ),
    instruction="""
You are a pediatric developmental specialist and part of a multi-model research team.

Your behavior:

1. First, call the `retrieve_child_profile` tool to get:
   - child's name
   - age in years
   - diagnosis / condition

2. If the tool returns an error (no profile found), respond with a short,
   clear message explaining that you cannot proceed without:
   - name
   - age
   - diagnosis.

3. If the profile is found, write a tailored answer for the parents, using this structure:

   - Start with: "For [NAME], [AGE] years old with [DIAGNOSIS], ..."
   - Then provide recommendations organized under:
       * language & communication
       * physical & movement
       * occupational & fine-motor
       * social & emotional
       * cognitive & learning

   - Make sure the recommendations are appropriate for the child's age
     (e.g., play-based, early intervention focus for a 3-year-old).

4. Be concise but specific, and write in a warm, supportive tone for the parents.

Your final answer will be saved as `gemini_research` and consumed by a downstream aggregator.
""",
    tools=[retrieve_child_profile_tool],
    output_key="gemini_research",
)

# %% [markdown]
# ### Profile agent
#
# Ensures Emma is in state at the start of the pipeline. We keep a profile agent that stores Emma:

# %%
profile_agent = LlmAgent(
    name="profile_agent",
    model=Gemini(model="gemini-2.5-flash-lite", retry_options=retry_config),
    description="Collects and stores child profile info in session state.",
    instruction="""
When the user describes their child (name, age, condition/diagnosis),
you MUST call `save_child_profile` to store those details in session state.

If the child profile is already stored and the user updates info
(e.g., a new age or additional diagnoses), call `save_child_profile` again.

Do NOT give therapy advice yourself.
""",
    tools=[save_child_profile, retrieve_child_profile],
)

# %% [markdown]
# ### Root pipeline
# #### profile → parallel research → aggregator

# %%
parallel_research_team = ParallelAgent(
    name="parallel_research_team",
    sub_agents=[gemini_researcher, gpt_researcher, claude_researcher],
)

aggregator_agent = LlmAgent(
    name="aggregator_agent",
    model=Gemini(
        model="gemini-2.5-flash-lite",
        retry_options=retry_config,
    ),
    tools=[retrieve_child_profile_tool],
    instruction="""
First, call `retrieve_child_profile` to get:
- child name
- age in years
- diagnosis

You are the final summarizer. You MUST produce exactly this structure in your answer:

1) First line:
   "Emma is [AGE] years old and has [DIAGNOSIS]."
   Use the actual name, age, and diagnosis from the profile.

2) Second line:
   A single, clear sentence:
   "Down syndrome is ..."

3) Then, a section titled:
   "Therapy Recommendations by Category"
   Under this, create subsections:

   - **Language & Communication**
     One concise paragraph summarizing what all three researchers agree on.
   - **Physical & Movement**
     One concise paragraph summarizing agreements.
   - **Occupational & Fine Motor**
     One concise paragraph summarizing agreements.
   - **Social & Emotional**
     One concise paragraph summarizing agreements.
   - **Cognitive & Learning**
     One concise paragraph summarizing agreements.

   These summaries MUST be based on:

   Gemini research:
   {gemini_research}

   GPT research:
   {gpt_research}

   Claude research:
   {claude_research}

4) Finally, add a section:
   "Differences Between Researchers"
   - If they largely agree, say that in one short sentence.
   - If there are differences (e.g., one suggests more professional therapy, another emphasizes home-based play), list 2–4 bullet points describing the key differences.

Tone: warm, clear, and parent-friendly. Do NOT repeat full long lists; only summarize.
""",
    output_key="final_summary",
)

root_agent = SequentialAgent(
    name="emma_research_system",
    sub_agents=[profile_agent, parallel_research_team, aggregator_agent],
)

# %% [markdown]
# ### Persistent sessions per child / family

# %%
APP_NAME = "genex_research_app"
USER_ID = "emma_parents"
DB_URL = "sqlite:///genex_sessions.db"

session_service = DatabaseSessionService(db_url=DB_URL)

research_app = App(
    name=APP_NAME,
    root_agent=root_agent,
    events_compaction_config=EventsCompactionConfig(
        compaction_interval=5,
        overlap_size=1,
    ),
)

runner = Runner(app=research_app, session_service=session_service)
# Out:
# C:\Users\T490\AppData\Local\Temp\ipykernel_19468\1568630742.py:10: UserWarning: [EXPERIMENTAL] EventsCompactionConfig: This feature is experimental and may change or be removed in future versions without notice. It may introduce breaking changes at any time.
#   events_compaction_config=EventsCompactionConfig(

# %% [markdown]
# #### First time

# %%
await runner.run_debug(
    "This is about my daughter Emma. She is 3 years old and has Down syndrome.",
    user_id="emma_parent",
    session_id="emma-session-001",
    quiet=True,
    verbose=False
)
# Out:
# Warning: there are non-text parts in the response: ['function_call'], returning concatenated text result from text parts. Check the full candidates.content.parts accessor to get the full model response.
# Warning: there are non-text parts in the response: ['function_call'], returning concatenated text result from text parts. Check the full candidates.content.parts accessor to get the full model response.
# Warning: there are non-text parts in the response: ['function_call'], returning concatenated text result from text parts. Check the full candidates.content.parts accessor to get the full model response.
# Warning: there are non-text parts in the response: ['function_call'], returning concatenated text result from text parts. Check the full candidates.content.parts accessor to get the full model response.
# [Event(model_version='gemini-2.5-flash-lite', content=Content(
#    parts=[
#      Part(
#        function_call=FunctionCall(
#          args={
#            'age_years': 3,
#            'diagnosis': 'Down syndrome',
#            'name': 'Emma'
#          },
#          id='adk-ee763f81-117a-47e6-9cc5-1afd56130504',
#          name='save_child_profile'
#        )
#      ),
#    ],
#    role='model'
#  ), grounding_metadata=None, partial=None, turn_complete=None, finish_reason=<FinishReason.STOP: 'STOP'>, error_code=None, error_message=None, interrupted=None, custom_metadata=None, usage_metadata=GenerateContentResponseUsageMetadata(
#    candidates_token_count=30,
#    prompt_token_count=249,
#    prompt_tokens_details=[
#      ModalityTokenCount(
#        modality=<MediaModality.TEXT: 'TEXT'>,
#        token_count=249
#      ),
#    ],
#    total_token_count=279
#  ), live_session_resumption_update=None, input_transcription=None, output_transcription=None, avg_logprobs=None, logprobs_result=None, cache_metadata=None, citation_metadata=None, invocation_id='e-2dd43bf3-9aae-4815-b69e-7120a4a9ac3a', author='profile_agent', actions=EventActions(skip_summarization=None, state_delta={}, artifact_delta={}, transfer_to_agent=None, escalate=None, requested_auth_configs={}, requested_tool_confirmations={}, compaction=None, end_of_agent=None, agent_state=None, rewind_before_invocation_id=None), long_running_tool_ids=set(), branch=None, id='6e39cd49-3497-41bb-ba01-15cf1e5eb02e', timestamp=1764357065.089986),
#  Event(model_version=None, content=Content(
#    parts=[
#      Part(
#        function_response=FunctionResponse(
#          id='adk-ee763f81-117a-47e6-9cc5-1afd56130504',
#          name='save_child_profile',
#          response={
#            'status': 'success'
#          }
#        )
#      ),
#    ],
#    role='user'
#  ), grounding_metadata=None, partial=None, turn_complete=None, finish_reason=None, error_code=None, error_message=None, interrupted=None, custom_metadata=None, usage_metadata=None, live_session_resumption_update=None, input_transcription=None, output_transcription=None, avg_logprobs=None, logprobs_result=None, cache_metadata=None, citation_metadata=None, invocation_id='e-2dd43bf3-9aae-4815-b69e-7120a4a9ac3a', author='profile_agent', actions=EventActions(skip_summarization=None, state_delta={'child:name': 'Emma', 'child:age_years': 3, 'child:diagnosis': 'Down syndrome'}, artifact_delta={}, transfer_to_agent=None, escalate=None, requested_auth_configs={}, requested_tool_confirmations={}, compaction=None, end_of_agent=None, agent_state=None, rewind_before_invocation_id=None), long_running_tool_ids=None, branch=None, id='7aa3d96e-da4b-46b0-a8b4-f5283a9202b5', timestamp=1764357066.453704),
#  Event(model_version='gemini-2.5-flash-lite', content=Content(
#    parts=[
#      Part(
#        text="I've saved Emma's profile. Is there anything else you'd like to add or update?"
#      ),
#    ],
#    role='model'
#  ), grounding_metadata=None, partial=None, turn_complete=None, finish_reason=<FinishReason.STOP: 'STOP'>, error_code=None, error_message=None, interrupted=None, custom_metadata=None, usage_metadata=GenerateContentResponseUsageMetadata(
#    candidates_token_count=22,
#    prompt_token_count=296,
#    prompt_tokens_details=[
#      ModalityTokenCount(
#        modality=<MediaModality.TEXT: 'TEXT'>,
#        token_count=296
#      ),
#    ],
#    total_token_count=318
#  ), live_session_resumption_update=None, input_transcription=None, output_transcription=None, avg_logprobs=None, logprobs_result=None, cache_metadata=None, citation_metadata=None, invocation_id='e-2dd43bf3-9aae-4815-b69e-7120a4a9ac3a', author='profile_agent', actions=EventActions(skip_summarization=None, state_delta={}, artifact_delta={}, transfer_to_agent=None, escalate=None, requested_auth_configs={}, requested_tool_confirmations={}, compaction=None, end_of_agent=None, agent_state=None, rewind_before_invocation_id=None), long_running_tool_ids=None, branch=None, id='3beec887-e3a5-4fab-affa-010ba3df3f51', timestamp=1764357066.470408),
#  Event(model_version='gemini-2.5-flash', content=Content(
#    parts=[
#      Part(
#        function_call=FunctionCall(
#          args={},
#          id='adk-5402b352-f907-4f9a-b503-ed4f3c9ea690',
#          name='retrieve_child_profile'
#        ),
#        thought_signature=b'\n\x9c\x02\x01r\xc8\xda|a\x18\xed\xd2`\x86\xd4\x84D8\xffW\xc3\xcb\xb1\xc1j\x1d\xf6\xc9QUb\x98\xfa\xbbi,\x8e\xfe\xe7xh7\\\xc8q\t\t\x12\xe6\xeeg\xb7\x96Fi%]w8\xce\xa4\t\xa7\xa4\xe0\x18\xc7w-?F\x92X\xfam\xfd^v\xfci\xa8\x00`\xe2 \xc1Un\\\x15#[\xadJ&\xf2\xaa...'
#      ),
#    ],
#    role='model'
#  ), grounding_metadata=None, partial=None, turn_complete=None, finish_reason=<FinishReason.STOP: 'STOP'>, error_code=None, error_message=None, interrupted=None, custom_metadata=None, usage_metadata=GenerateContentResponseUsageMetadata(
#    candidates_token_count=12,
#    prompt_token_count=438,
#    prompt_tokens_details=[
#      ModalityTokenCount(
#        modality=<MediaModality.TEXT: 'TEXT'>,
#        token_count=438
#      ),
#    ],
#    thoughts_token_count=54,
#    total_token_count=504
#  ), live_session_resumption_update=None, input_transcription=None, output_transcription=None, avg_logprobs=None, logprobs_result=None, cache_metadata=None, citation_metadata=None, invocation_id='e-2dd43bf3-9aae-4815-b69e-7120a4a9ac3a', author='gemini_researcher', actions=EventActions(skip_summarization=None, state_delta={}, artifact_delta={}, transfer_to_agent=None, escalate=None, requested_auth_configs={}, requested_tool_confirmations={}, compaction=None, end_of_agent=None, agent_state=None, rewind_before_invocation_id=None), long_running_tool_ids=set(), branch='parallel_research_team.gemini_researcher', id='ec4e0218-a81e-4b7f-9437-523042cbc266', timestamp=1764357067.121666),
#  Event(model_version=None, content=Content(
#    parts=[
#      Part(
#        function_response=FunctionResponse(
#          id='adk-5402b352-f907-4f9a-b503-ed4f3c9ea690',
#          name='retrieve_child_profile',
#          response={
#            'age_years': 3,
#            'diagnosis': 'Down syndrome',
#            'name': 'Emma',
#            'status': 'success'
#          }
#        )
#      ),
#    ],
#    role='user'
#  ), grounding_metadata=None, partial=None, turn_complete=None, finish_reason=None, error_code=None, error_message=None, interrupted=None, custom_metadata=None, usage_metadata=None, live_session_resumption_update=None, input_transcription=None, output_transcription=None, avg_logprobs=None, logprobs_result=None, cache_metadata=None, citation_metadata=None, invocation_id='e-2dd43bf3-9aae-4815-b69e-7120a4a9ac3a', author='gemini_researcher', actions=EventActions(skip_summarization=None, state_delta={}, artifact_delta={}, transfer_to_agent=None, escalate=None, requested_auth_configs={}, requested_tool_confirmations={}, compaction=None, end_of_agent=None, agent_state=None, rewind_before_invocation_id=None), long_running_tool_ids=None, branch='parallel_research_team.gemini_researcher', id='a2e243c8-f74d-4006-8ded-040778d4408b', timestamp=1764357069.866839),
#  Event(model_version='gemini-2.5-flash', content=Content(
#    parts=[
#      Part(
#        function_call=FunctionCall(
#          args={},
#          id='adk-b623b0c1-a4a7-48bf-be7d-2ad81c47781e',
#          name='gpt_child_research_tool'
#        ),
#        thought_signature=b'\n\xb6\x03\x01r\xc8\xda|x\x97-\x03\xd1 \xde\xe6\x18\x9d\x92\xe7\x1c\xea\xf67\x85\xefQ\x8a\t\xf4\x8f\x17S\x1c\xa9\xf9E4R\x07\xe8\xa3Nw&\x905\xf4\x89\xba\xf5\x91\xfeC9\x9c\x106!\x97h\xd9\xb4\xb5[\x03\xe1$\xedU\x12L*p\x18\xf3\r\xd1}\xf8\x8f\x8b\x82p}\x0c<\xee\xbd\x9d$\x08\x90] \xf5\xbf...'
#      ),
#    ],
#    role='model'
#  ), grounding_metadata=None, partial=None, turn_complete=None, finish_reason=<FinishReason.STOP: 'STOP'>, error_code=None, error_message=None, interrupted=None, custom_metadata=None, usage_metadata=GenerateContentResponseUsageMetadata(
#    candidates_token_count=14,
#    prompt_token_count=212,
#    prompt_tokens_details=[
#      ModalityTokenCount(
#        modality=<MediaModality.TEXT: 'TEXT'>,
#        token_count=212
#      ),
#    ],
#    thoughts_token_count=89,
#    total_token_count=315
#  ), live_session_resumption_update=None, input_transcription=None, output_transcription=None, avg_logprobs=None, logprobs_result=None, cache_metadata=None, citation_metadata=None, invocation_id='e-2dd43bf3-9aae-4815-b69e-7120a4a9ac3a', author='gpt_researcher', actions=EventActions(skip_summarization=None, state_delta={}, artifact_delta={}, transfer_to_agent=None, escalate=None, requested_auth_configs={}, requested_tool_confirmations={}, compaction=None, end_of_agent=None, agent_state=None, rewind_before_invocation_id=None), long_running_tool_ids=set(), branch='parallel_research_team.gpt_researcher', id='38fc77b2-932c-4e7c-9c6e-1ab38fd02349', timestamp=1764357067.697923),
#  Event(model_version=None, content=Content(
#    parts=[
#      Part(
#        function_response=FunctionResponse(
#          id='adk-b623b0c1-a4a7-48bf-be7d-2ad81c47781e',
#          name='gpt_child_research_tool',
#          response={
#            'gpt_research': """1. Down syndrome is a genetic condition that can affect Emma's physical and cognitive development, making early intervention and support crucial for her growth and progress at this age.
#
#  2. Here are some recommended therapies tailored specifically for Emma's age and condition:
#
#     - **Language/Communication**: Encourage interactive reading sessions with simple, colorful picture books, and engage Emma in frequent, short conversations to enhance her vocabulary and speech clarity while using visual cues and gestures to support understanding.
#
#     - **Physical/Movement**: Incorporate fun, playful activities such as climbing, dancing, or participating in structured playgroups that focus on gross motor skills development, like running and jumping, to help improve her coordination and balance.
#
#     - **Occupational/Fine Motor**: Offer opportunities for engaging in arts and crafts with safe materials, such as crayons or finger paints, and simple activities like stacking blocks or stringing large beads to enhance her hand-eye coordination and fine motor skills.
#
#     - **Social/Emotional**: Foster social interactions by arranging playdates with peers, encouraging turn-taking games, and providing positive reinforcement to help Emma build confidence and learn social cues in a supportive environment.
#
#     - **Cognitive/Learning**: Use simple, structured learning activities like sorting shapes, matching colors, or participating in basic puzzles, along with daily routines to encourage problem-solving and cognitive development through play-based learning.""",
#            'status': 'success'
#          }
#        )
#      ),
#    ],
#    role='user'
#  ), grounding_metadata=None, partial=None, turn_complete=None, finish_reason=None, error_code=None, error_message=None, interrupted=None, custom_metadata=None, usage_metadata=None, live_session_resumption_update=None, input_transcription=None, output_transcription=None, avg_logprobs=None, logprobs_result=None, cache_metadata=None, citation_metadata=None, invocation_id='e-2dd43bf3-9aae-4815-b69e-7120a4a9ac3a', author='gpt_researcher', actions=EventActions(skip_summarization=None, state_delta={}, artifact_delta={}, transfer_to_agent=None, escalate=None, requested_auth_configs={}, requested_tool_confirmations={}, compaction=None, end_of_agent=None, agent_state=None, rewind_before_invocation_id=None), long_running_tool_ids=None, branch='parallel_research_team.gpt_researcher', id='27f1d423-86ad-463e-aaf8-b9745367b599', timestamp=1764357077.260167),
#  Event(model_version='gemini-2.5-flash', content=Content(
#    parts=[
#      Part(
#        function_call=FunctionCall(
#          args={},
#          id='adk-34e13384-ce2f-492d-8a25-6e6e51de07da',
#          name='claude_child_research_tool'
#        ),
#        thought_signature=b'\n\xa5\x07\x01r\xc8\xda|\xc8\xe8t\x98\x1b]\x9b\xf8\x0f@\x89O\n\xa7\x91]\xac\x13Nt\xd3\xa1\xde\xdd\x91\x87x\xcc\x04D\xa1P\xa8\x8e\x8d\x0c\xcd\x89h^\x95\xfc\x0e\x7f\r\xfa\xe1\xd4\xae\x8a\xfd\xd3\x16H\xb1\xe9\xb2\xe6M\xa24T;{\xe8\xd9\x0f\x08?\xfaU\x7f\x86QJ\x9cLt\x1b1\x8b\xdf%\xb2\x0b\x9c\xca\x0f&...'
#      ),
#    ],
#    role='model'
#  ), grounding_metadata=None, partial=None, turn_complete=None, finish_reason=<FinishReason.STOP: 'STOP'>, error_code=None, error_message=None, interrupted=None, custom_metadata=None, usage_metadata=GenerateContentResponseUsageMetadata(
#    candidates_token_count=15,
#    prompt_token_count=202,
#    prompt_tokens_details=[
#      ModalityTokenCount(
#        modality=<MediaModality.TEXT: 'TEXT'>,
#        token_count=202
#      ),
#    ],
#    thoughts_token_count=196,
#    total_token_count=413
#  ), live_session_resumption_update=None, input_transcription=None, output_transcription=None, avg_logprobs=None, logprobs_result=None, cache_metadata=None, citation_metadata=None, invocation_id='e-2dd43bf3-9aae-4815-b69e-7120a4a9ac3a', author='claude_researcher', actions=EventActions(skip_summarization=None, state_delta={}, artifact_delta={}, transfer_to_agent=None, escalate=None, requested_auth_configs={}, requested_tool_confirmations={}, compaction=None, end_of_agent=None, agent_state=None, rewind_before_invocation_id=None), long_running_tool_ids=set(), branch='parallel_research_team.claude_researcher', id='11cc3d8e-49af-4cd9-a268-0d31e494fac2', timestamp=1764357068.247404),
#  Event(model_version='gemini-2.5-flash', content=Content(
#    parts=[
#      Part(
#        text="""For Emma, 3 years old with Down syndrome, here are some recommendations to support her development:
#
#  *   **Language & Communication:**
#      Encourage consistent eye contact and respond to her babbles and gestures. Use simple language, short sentences, and visual aids like picture cards to help her understand and express herself. Sign language can also be a wonderful tool for early communication. Read engaging storybooks together daily, pointing to pictures and naming objects.
#
#  *   **Physical & Movement:**
#      Provide opportunities for active play that strengthens her muscles and improves coordination, such as crawling through tunnels, climbing on low structures, and playing with large balls. Encourage activities that promote balance, like walking on uneven surfaces or dancing to music. Early intervention physical therapy can be very beneficial for gross motor skill development.
#
#  *   **Occupational & Fine-Motor:**
#      Offer activities that develop her hand-eye coordination and fine motor skills. This can include stacking blocks, playing with shape sorters, manipulating playdough, tearing paper, and coloring with chunky crayons. Encourage self-feeding with child-friendly utensils and dressing with simple clothes.
#
#  *   **Social & Emotional:**
#      Facilitate playdates with peers to encourage social interaction and turn-taking. Praise her efforts and successes to build her self-esteem. Model appropriate social behaviors and help her identify and express her feelings through words or pictures. Consistent routines can provide a sense of security and predictability.
#
#  *   **Cognitive & Learning:**
#      Engage her in play that involves problem-solving, like simple puzzles or matching games. Introduce early concepts such as colors, shapes, and numbers through songs, books, and everyday activities. Encourage exploration and curiosity by providing a stimulating environment with various textures, sounds, and objects to interact with. Repetition and consistency are key for learning new skills.""",
#        thought_signature=b'\n\xec\x04\x01r\xc8\xda|\xcb\x0f\xbc\x0ca\xc5\xd1\xc5d7\xd1Z\xbe\xe8W\x94\x9b\xfd\xde\x01BPj(h\xe6\xce,q\xeat9b\xeb\x99F\xcaS\xab\x81\xf5k\x1bt&\xebq \xd3:A( !\x9c\xfb\xa3\xf49(Bs\x84o\xd8\xf1^(E5-\xbf\xab=%;\\\xc2\xd2f\xc85>\xee\xbc\x87\x16\xa2\xe2...'
#      ),
#    ],
#    role='model'
#  ), grounding_metadata=None, partial=None, turn_complete=None, finish_reason=<FinishReason.STOP: 'STOP'>, error_code=None, error_message=None, interrupted=None, custom_metadata=None, usage_metadata=GenerateContentResponseUsageMetadata(
#    candidates_token_count=376,
#    prompt_token_count=488,
#    prompt_tokens_details=[
#      ModalityTokenCount(
#        modality=<MediaModality.TEXT: 'TEXT'>,
#        token_count=488
#      ),
#    ],
#    thoughts_token_count=134,
#    total_token_count=998
#  ), live_session_resumption_update=None, input_transcription=None, output_transcription=None, avg_logprobs=None, logprobs_result=None, cache_metadata=None, citation_metadata=None, invocation_id='e-2dd43bf3-9aae-4815-b69e-7120a4a9ac3a', author='gemini_researcher', actions=EventActions(skip_summarization=None, state_delta={'gemini_research': 'For Emma, 3 years old with Down syndrome, here are some recommendations to support her development:\n\n*   **Language & Communication:**\n    Encourage consistent eye contact and respond to her babbles and gestures. Use simple language, short sentences, and visual aids like picture cards to help her understand and express herself. Sign language can also be a wonderful tool for early communication. Read engaging storybooks together daily, pointing to pictures and naming objects.\n\n*   **Physical & Movement:**\n    Provide opportunities for active play that strengthens her muscles and improves coordination, such as crawling through tunnels, climbing on low structures, and playing with large balls. Encourage activities that promote balance, like walking on uneven surfaces or dancing to music. Early intervention physical therapy can be very beneficial for gross motor skill development.\n\n*   **Occupational & Fine-Motor:**\n    Offer activities that develop her hand-eye coordination and fine motor skills. This can include stacking blocks, playing with shape sorters, manipulating playdough, tearing paper, and coloring with chunky crayons. Encourage self-feeding with child-friendly utensils and dressing with simple clothes.\n\n*   **Social & Emotional:**\n    Facilitate playdates with peers to encourage social interaction and turn-taking. Praise her efforts and successes to build her self-esteem. Model appropriate social behaviors and help her identify and express her feelings through words or pictures. Consistent routines can provide a sense of security and predictability.\n\n*   **Cognitive & Learning:**\n    Engage her in play that involves problem-solving, like simple puzzles or matching games. Introduce early concepts such as colors, shapes, and numbers through songs, books, and everyday activities. Encourage exploration and curiosity by providing a stimulating environment with various textures, sounds, and objects to interact with. Repetition and consistency are key for learning new skills.'}, artifact_delta={}, transfer_to_agent=None, escalate=None, requested_auth_configs={}, requested_tool_confirmations={}, compaction=None, end_of_agent=None, agent_state=None, rewind_before_invocation_id=None), long_running_tool_ids=None, branch='parallel_research_team.gemini_researcher', id='b2467fb5-dc6e-4305-a51d-7ccd9f92cc0c', timestamp=1764357069.881102),
#  Event(model_version=None, content=Content(
#    parts=[
#      Part(
#        function_response=FunctionResponse(
#          id='adk-34e13384-ce2f-492d-8a25-6e6e51de07da',
#          name='claude_child_research_tool',
#          response={
#            'claude_research': """Down Syndrome Overview:
#  Down syndrome is a genetic condition caused by an extra copy of chromosome 21 that affects Emma's physical development, cognitive abilities, and can impact her learning and developmental milestones, but with early intervention and supportive therapies, she can make significant progress and lead a fulfilling life.
#
#  Recommended Therapies for Emma:
#
#  1. Language/Communication:
#  - Work with a speech therapist who specializes in children with Down syndrome to support her verbal and non-verbal communication skills
#  - Use picture cards, sign language, and simple verbal prompts to encourage her language development
#  - Practice short, clear instructions and give her extra time to process and respond
#
#  2. Physical/Movement:
#  - Engage her in physical therapy to support muscle tone, balance, and gross motor skill development
#  - Encourage activities like swimming, walking on different surfaces, climbing playground equipment
#  - Consider adaptive equipment or supportive shoes to help with stability and coordination
#  - Do daily stretching and gentle exercises to improve muscle strength
#
#  3. Occupational/Fine Motor:
#  - Use play-based activities to develop her fine motor skills like stacking blocks, using large crayons, threading large beads
#  - Practice self-care skills like holding utensils, buttoning large buttons, zipping simple zippers
#  - Provide tools and toys that are easy to grasp and manipulate
#
#  4. Social/Emotional:
#  - Enroll her in inclusive preschool or playgroups to develop social skills
#  - Use positive reinforcement and celebrate her achievements
#  - Help her identify and express emotions through simple games and conversations
#  - Provide consistent routine and predictable social interactions
#
#  5. Cognitive/Learning:
#  - Use repetitive, visual learning strategies
#  - Implement short, engaging learning sessions
#  - Use educational toys that encourage problem-solving
#  - Work closely with early intervention specialists to create a personalized learning plan
#  - Read together daily and use interactive, colorful books
#
#  Remember, every child with Down syndrome is unique. Emma will progress at her own pace, and your love, patience, and consistent support are her most important resources.""",
#            'status': 'success'
#          }
#        )
#      ),
#    ],
#    role='user'
#  ), grounding_metadata=None, partial=None, turn_complete=None, finish_reason=None, error_code=None, error_message=None, interrupted=None, custom_metadata=None, usage_metadata=None, live_session_resumption_update=None, input_transcription=None, output_transcription=None, avg_logprobs=None, logprobs_result=None, cache_metadata=None, citation_metadata=None, invocation_id='e-2dd43bf3-9aae-4815-b69e-7120a4a9ac3a', author='claude_researcher', actions=EventActions(skip_summarization=None, state_delta={}, artifact_delta={}, transfer_to_agent=None, escalate=None, requested_auth_configs={}, requested_tool_confirmations={}, compaction=None, end_of_agent=None, agent_state=None, rewind_before_invocation_id=None), long_running_tool_ids=None, branch='parallel_research_team.claude_researcher', id='b2109912-280a-4e7e-a820-9dcb210025d6', timestamp=1764357087.373131),
#  Event(model_version='gemini-2.5-flash', content=Content(
#    parts=[
#      Part(
#        text="""That's great! Here are some therapy recommendations tailored for Emma, considering she is 3 years old and has Down syndrome:
#
#  **1. Down syndrome is a genetic condition that can affect Emma's physical and cognitive development, making early intervention and support crucial for her growth and progress at this age.**
#
#  **2. Here are some recommended therapies tailored specifically for Emma's age and condition:**
#
#  *   **Language/Communication**: Encourage interactive reading sessions with simple, colorful picture books, and engage Emma in frequent, short conversations to enhance her vocabulary and speech clarity while using visual cues and gestures to support understanding.
#  *   **Physical/Movement**: Incorporate fun, playful activities such as climbing, dancing, or participating in structured playgroups that focus on gross motor skills development, like running and jumping, to help improve her coordination and balance.
#  *   **Occupational/Fine Motor**: Offer opportunities for engaging in arts and crafts with safe materials, such as crayons or finger paints, and simple activities like stacking blocks or stringing large beads to enhance her hand-eye coordination and fine motor skills.
#  *   **Social/Emotional**: Foster social interactions by arranging playdates with peers, encouraging turn-taking games, and providing positive reinforcement to help Emma build confidence and learn social cues in a supportive environment.
#  *   **Cognitive/Learning**: Use simple, structured learning activities like sorting shapes, matching colors, or participating in basic puzzles, along with daily routines to encourage problem-solving and cognitive development through play-based learning.
#
#  Would you like to explore any of these areas further, or perhaps discuss specific activities within these therapies?
#  """
#      ),
#    ],
#    role='model'
#  ), grounding_metadata=None, partial=None, turn_complete=None, finish_reason=<FinishReason.STOP: 'STOP'>, error_code=None, error_message=None, interrupted=None, custom_metadata=None, usage_metadata=GenerateContentResponseUsageMetadata(
#    candidates_token_count=333,
#    prompt_token_count=546,
#    prompt_tokens_details=[
#      ModalityTokenCount(
#        modality=<MediaModality.TEXT: 'TEXT'>,
#        token_count=546
#      ),
#    ],
#    total_token_count=879
#  ), live_session_resumption_update=None, input_transcription=None, output_transcription=None, avg_logprobs=None, logprobs_result=None, cache_metadata=None, citation_metadata=None, invocation_id='e-2dd43bf3-9aae-4815-b69e-7120a4a9ac3a', author='gpt_researcher', actions=EventActions(skip_summarization=None, state_delta={'gpt_research': "That's great! Here are some therapy recommendations tailored for Emma, considering she is 3 years old and has Down syndrome:\n\n**1. Down syndrome is a genetic condition that can affect Emma's physical and cognitive development, making early intervention and support crucial for her growth and progress at this age.**\n\n**2. Here are some recommended therapies tailored specifically for Emma's age and condition:**\n\n*   **Language/Communication**: Encourage interactive reading sessions with simple, colorful picture books, and engage Emma in frequent, short conversations to enhance her vocabulary and speech clarity while using visual cues and gestures to support understanding.\n*   **Physical/Movement**: Incorporate fun, playful activities such as climbing, dancing, or participating in structured playgroups that focus on gross motor skills development, like running and jumping, to help improve her coordination and balance.\n*   **Occupational/Fine Motor**: Offer opportunities for engaging in arts and crafts with safe materials, such as crayons or finger paints, and simple activities like stacking blocks or stringing large beads to enhance her hand-eye coordination and fine motor skills.\n*   **Social/Emotional**: Foster social interactions by arranging playdates with peers, encouraging turn-taking games, and providing positive reinforcement to help Emma build confidence and learn social cues in a supportive environment.\n*   **Cognitive/Learning**: Use simple, structured learning activities like sorting shapes, matching colors, or participating in basic puzzles, along with daily routines to encourage problem-solving and cognitive development through play-based learning.\n\nWould you like to explore any of these areas further, or perhaps discuss specific activities within these therapies?\n"}, artifact_delta={}, transfer_to_agent=None, escalate=None, requested_auth_configs={}, requested_tool_confirmations={}, compaction=None, end_of_agent=None, agent_state=None, rewind_before_invocation_id=None), long_running_tool_ids=None, branch='parallel_research_team.gpt_researcher', id='f8afc688-18a5-43a7-bb68-fc6b4300c9ba', timestamp=1764357077.292205),
#  Event(model_version='gemini-2.5-flash', content=Content(
#    parts=[
#      Part(
#        text="""Here's some information regarding Down syndrome and recommended therapies for Emma, based on her profile:
#
#  **Down Syndrome Overview:**
#  Down syndrome is a genetic condition caused by an extra copy of chromosome 21 that affects Emma's physical development, cognitive abilities, and can impact her learning and developmental milestones. However, with early intervention and supportive therapies, she can make significant progress and lead a fulfilling life.
#
#  **Recommended Therapies for Emma:**
#
#  1.  **Language/Communication:**
#      *   Work with a speech therapist who specializes in children with Down syndrome to support her verbal and non-verbal communication skills.
#      *   Use picture cards, sign language, and simple verbal prompts to encourage her language development.
#      *   Practice short, clear instructions and give her extra time to process and respond.
#
#  2.  **Physical/Movement:**
#      *   Engage her in physical therapy to support muscle tone, balance, and gross motor skill development.
#      *   Encourage activities like swimming, walking on different surfaces, and climbing playground equipment.
#      *   Consider adaptive equipment or supportive shoes to help with stability and coordination.
#      *   Do daily stretching and gentle exercises to improve muscle strength.
#
#  3.  **Occupational/Fine Motor:**
#      *   Use play-based activities to develop her fine motor skills like stacking blocks, using large crayons, and threading large beads.
#      *   Practice self-care skills like holding utensils, buttoning large buttons, and zipping simple zippers.
#      *   Provide tools and toys that are easy to grasp and manipulate.
#
#  4.  **Social/Emotional:**
#      *   Enroll her in inclusive preschool or playgroups to develop social skills.
#      *   Use positive reinforcement and celebrate her achievements.
#      *   Help her identify and express emotions through simple games and conversations.
#      *   Provide consistent routines and predictable social interactions.
#
#  5.  **Cognitive/Learning:**
#      *   Use repetitive, visual learning strategies.
#      *   Implement short, engaging learning sessions.
#      *   Use educational toys that encourage problem-solving.
#      *   Work closely with early intervention specialists to create a personalized learning plan.
#      *   Read together daily and use interactive, colorful books.
#
#  Remember, every child with Down syndrome is unique. Emma will progress at her own pace, and your love, patience, and consistent support are her most important resources.""",
#        thought_signature=b'\n\xc5\x03\x01r\xc8\xda|HZl\xbb\x80\xf9To\xe8\x81L@\xbarX\xc9y]y=y\xe1\xd3\xa3\xc5\x9e)\x8b\xb1\x88k\xa2\xd6\xac\xf5x\x1eA~h\xad\xbc\x11:%\x1bEbE\x8d\xe5r\x95,\x04`\xa3\xce\xdf\xbb\xaa\xa9\x82\xed \x17\xed\xd5\xec\xc0\x02\xd2\xc7J\xf9\xd5\xc7\x1e\xdej2\x10\xf5#\xc2\x84@.\xcd...'
#      ),
#    ],
#    role='model'
#  ), grounding_metadata=None, partial=None, turn_complete=None, finish_reason=<FinishReason.STOP: 'STOP'>, error_code=None, error_message=None, interrupted=None, custom_metadata=None, usage_metadata=GenerateContentResponseUsageMetadata(
#    candidates_token_count=505,
#    prompt_token_count=685,
#    prompt_tokens_details=[
#      ModalityTokenCount(
#        modality=<MediaModality.TEXT: 'TEXT'>,
#        token_count=685
#      ),
#    ],
#    thoughts_token_count=83,
#    total_token_count=1273
#  ), live_session_resumption_update=None, input_transcription=None, output_transcription=None, avg_logprobs=None, logprobs_result=None, cache_metadata=None, citation_metadata=None, invocation_id='e-2dd43bf3-9aae-4815-b69e-7120a4a9ac3a', author='claude_researcher', actions=EventActions(skip_summarization=None, state_delta={'claude_research': "Here's some information regarding Down syndrome and recommended therapies for Emma, based on her profile:\n\n**Down Syndrome Overview:**\nDown syndrome is a genetic condition caused by an extra copy of chromosome 21 that affects Emma's physical development, cognitive abilities, and can impact her learning and developmental milestones. However, with early intervention and supportive therapies, she can make significant progress and lead a fulfilling life.\n\n**Recommended Therapies for Emma:**\n\n1.  **Language/Communication:**\n    *   Work with a speech therapist who specializes in children with Down syndrome to support her verbal and non-verbal communication skills.\n    *   Use picture cards, sign language, and simple verbal prompts to encourage her language development.\n    *   Practice short, clear instructions and give her extra time to process and respond.\n\n2.  **Physical/Movement:**\n    *   Engage her in physical therapy to support muscle tone, balance, and gross motor skill development.\n    *   Encourage activities like swimming, walking on different surfaces, and climbing playground equipment.\n    *   Consider adaptive equipment or supportive shoes to help with stability and coordination.\n    *   Do daily stretching and gentle exercises to improve muscle strength.\n\n3.  **Occupational/Fine Motor:**\n    *   Use play-based activities to develop her fine motor skills like stacking blocks, using large crayons, and threading large beads.\n    *   Practice self-care skills like holding utensils, buttoning large buttons, and zipping simple zippers.\n    *   Provide tools and toys that are easy to grasp and manipulate.\n\n4.  **Social/Emotional:**\n    *   Enroll her in inclusive preschool or playgroups to develop social skills.\n    *   Use positive reinforcement and celebrate her achievements.\n    *   Help her identify and express emotions through simple games and conversations.\n    *   Provide consistent routines and predictable social interactions.\n\n5.  **Cognitive/Learning:**\n    *   Use repetitive, visual learning strategies.\n    *   Implement short, engaging learning sessions.\n    *   Use educational toys that encourage problem-solving.\n    *   Work closely with early intervention specialists to create a personalized learning plan.\n    *   Read together daily and use interactive, colorful books.\n\nRemember, every child with Down syndrome is unique. Emma will progress at her own pace, and your love, patience, and consistent support are her most important resources."}, artifact_delta={}, transfer_to_agent=None, escalate=None, requested_auth_configs={}, requested_tool_confirmations={}, compaction=None, end_of_agent=None, agent_state=None, rewind_before_invocation_id=None), long_running_tool_ids=None, branch='parallel_research_team.claude_researcher', id='bb17dec3-41a1-4f72-9cf6-4f801e5a1f54', timestamp=1764357087.408273),
#  Event(model_version='gemini-2.5-flash-lite', content=Content(
#    parts=[
#      Part(
#        text="""Emma is 3 years old and has Down syndrome.
#  Down syndrome is a genetic condition caused by an extra copy of chromosome 21 that affects physical development, cognitive abilities, and learning.
#  Therapy Recommendations by Category
#  **Language & Communication**
#  All three researchers recommend using simple language and short sentences, visual aids like picture cards, and encouraging verbal and non-verbal communication. They also suggest reading together daily and using interactive books. Gemini and Claude specifically mention sign language as a beneficial tool.
#
#  **Physical & Movement**
#  The researchers agree on the importance of active play for gross motor skills, coordination, and balance. Activities like climbing, dancing, and playing with balls are recommended. Gemini suggests crawling through tunnels, while Claude mentions swimming and walking on different surfaces. Claude also highlights the benefit of physical therapy and adaptive equipment.
#
#  **Occupational & Fine Motor**
#  All researchers emphasize play-based activities to develop fine motor skills and hand-eye coordination. Recommended activities include stacking blocks, using crayons, and manipulating playdough. Claude also suggests practicing self-care skills like buttoning and using utensils, and ensuring tools are easy to grasp.
#
#  **Social & Emotional**
#  The consensus is to foster social interaction through playdates and peer groups, encourage turn-taking, and use positive reinforcement to build self-esteem. All researchers agree on the importance of helping Emma identify and express emotions and providing consistent routines for security.
#
#  **Cognitive & Learning**
#  The researchers recommend engaging Emma in play-based learning that involves problem-solving, such as puzzles and matching games. They suggest using simple, structured activities, repetition, and visual strategies. Gemini and Claude specifically mention introducing early concepts like colors and shapes, while Claude adds working with early intervention specialists.
#
#  Differences Between Researchers
#  The researchers largely agree on the core therapeutic approaches.
#  *   Claude more strongly emphasizes seeking professional intervention, specifically mentioning speech therapists and physical therapists, and considering adaptive equipment.
#  *   Gemini and GPT-4 focus more broadly on play-based activities and home-based strategies, though Gemini does mention early intervention physical therapy.
#  *   Claude provides a more detailed overview of Down syndrome itself in addition to the therapy recommendations."""
#      ),
#    ],
#    role='model'
#  ), grounding_metadata=None, partial=None, turn_complete=None, finish_reason=<FinishReason.STOP: 'STOP'>, error_code=None, error_message=None, interrupted=None, custom_metadata=None, usage_metadata=GenerateContentResponseUsageMetadata(
#    candidates_token_count=446,
#    prompt_token_count=3913,
#    prompt_tokens_details=[
#      ModalityTokenCount(
#        modality=<MediaModality.TEXT: 'TEXT'>,
#        token_count=3913
#      ),
#    ],
#    total_token_count=4359
#  ), live_session_resumption_update=None, input_transcription=None, output_transcription=None, avg_logprobs=None, logprobs_result=None, cache_metadata=None, citation_metadata=None, invocation_id='e-2dd43bf3-9aae-4815-b69e-7120a4a9ac3a', author='aggregator_agent', actions=EventActions(skip_summarization=None, state_delta={'final_summary': 'Emma is 3 years old and has Down syndrome.\nDown syndrome is a genetic condition caused by an extra copy of chromosome 21 that affects physical development, cognitive abilities, and learning.\nTherapy Recommendations by Category\n**Language & Communication**\nAll three researchers recommend using simple language and short sentences, visual aids like picture cards, and encouraging verbal and non-verbal communication. They also suggest reading together daily and using interactive books. Gemini and Claude specifically mention sign language as a beneficial tool.\n\n**Physical & Movement**\nThe researchers agree on the importance of active play for gross motor skills, coordination, and balance. Activities like climbing, dancing, and playing with balls are recommended. Gemini suggests crawling through tunnels, while Claude mentions swimming and walking on different surfaces. Claude also highlights the benefit of physical therapy and adaptive equipment.\n\n**Occupational & Fine Motor**\nAll researchers emphasize play-based activities to develop fine motor skills and hand-eye coordination. Recommended activities include stacking blocks, using crayons, and manipulating playdough. Claude also suggests practicing self-care skills like buttoning and using utensils, and ensuring tools are easy to grasp.\n\n**Social & Emotional**\nThe consensus is to foster social interaction through playdates and peer groups, encourage turn-taking, and use positive reinforcement to build self-esteem. All researchers agree on the importance of helping Emma identify and express emotions and providing consistent routines for security.\n\n**Cognitive & Learning**\nThe researchers recommend engaging Emma in play-based learning that involves problem-solving, such as puzzles and matching games. They suggest using simple, structured activities, repetition, and visual strategies. Gemini and Claude specifically mention introducing early concepts like colors and shapes, while Claude adds working with early intervention specialists.\n\nDifferences Between Researchers\nThe researchers largely agree on the core therapeutic approaches.\n*   Claude more strongly emphasizes seeking professional intervention, specifically mentioning speech therapists and physical therapists, and considering adaptive equipment.\n*   Gemini and GPT-4 focus more broadly on play-based activities and home-based strategies, though Gemini does mention early intervention physical therapy.\n*   Claude provides a more detailed overview of Down syndrome itself in addition to the therapy recommendations.'}, artifact_delta={}, transfer_to_agent=None, escalate=None, requested_auth_configs={}, requested_tool_confirmations={}, compaction=None, end_of_agent=None, agent_state=None, rewind_before_invocation_id=None), long_running_tool_ids=None, branch=None, id='0f37e3e5-afe8-49d1-9f6c-101d41096ff5', timestamp=1764357090.297971)]

# %%
events = await runner.run_debug(
    "What therapies do you recommend for her overall development?",
    user_id="emma_parent",
    session_id="emma-session-001",
    quiet=True,
    verbose=False
)
# Out:
# Warning: there are non-text parts in the response: ['function_call'], returning concatenated text result from text parts. Check the full candidates.content.parts accessor to get the full model response.
# Warning: there are non-text parts in the response: ['function_call'], returning concatenated text result from text parts. Check the full candidates.content.parts accessor to get the full model response.
# Warning: there are non-text parts in the response: ['function_call'], returning concatenated text result from text parts. Check the full candidates.content.parts accessor to get the full model response.

# %%
final_event = events[-1]  # last event comes from aggregator agent
final_summary = final_event.actions.state_delta["final_summary"]

print(final_summary)
# Out:
# Emma is 3 years old and has Down syndrome.
# Down syndrome is a genetic condition caused by an extra copy of chromosome 21 that affects physical development, cognitive abilities, and learning.
# Therapy Recommendations by Category
# **Language & Communication**
# All three researchers emphasize using simple language, short sentences, and visual aids like picture cards to support understanding and expression. They all recommend interactive reading and agree on the benefits of encouraging both verbal and non-verbal communication. Gemini and Claude specifically suggest sign language as a helpful tool.
#
# **Physical & Movement**
# There is a strong consensus among the researchers on the importance of active play for developing gross motor skills, coordination, and balance. Recommended activities include climbing, dancing, and playing with balls. Gemini also suggests crawling through tunnels, while Claude mentions swimming and walking on various surfaces. Claude specifically recommends consulting with a physical therapist.
#
# **Occupational & Fine Motor**
# The researchers agree on the value of play-based activities for enhancing fine motor skills and hand-eye coordination. Common suggestions include stacking blocks, using crayons, and threading beads. Claude also highlights the importance of practicing self-care skills like buttoning and using utensils, and ensuring that toys and tools are easy for Emma to handle.
#
# **Social & Emotional**
# All researchers advocate for facilitating social interactions through playdates or inclusive groups to promote turn-taking and social skills. They agree on the importance of positive reinforcement to build confidence and on helping Emma identify and express her emotions. Maintaining consistent routines is also recommended by all for providing a sense of security.
#
# **Cognitive & Learning**
# The consensus is to engage Emma in playful activities that promote problem-solving skills, such as puzzles and matching games. Researchers suggest using repetitive and visual learning strategies, with short, engaging sessions. Introducing early concepts like colors and shapes through songs, books, and daily experiences is also recommended.
#
# Differences Between Researchers
# The researchers largely agree on the therapeutic approaches recommended for Emma's overall development.
# *   Claude's recommendations lean more towards professional therapies, suggesting consultation with speech and physical therapists, and considering adaptive equipment.
# *   Gemini and GPT-4 offer a blend of home-based activities and mention early intervention, with Gemini specifically noting early intervention physical therapy.
# *   Claude also provides a more detailed overview of Down syndrome itself as a condition.

# %% [markdown]
# #### Later

# %%
await runner.run_debug(
    "Can you suggest more fine-motor activities for Emma?",
    user_id=USER_ID,
    session_id="emma-session-001",
)
# Out:
#  ### Continue session: emma-session-001
#
# User > Can you suggest more fine-motor activities for Emma?
# profile_agent > Here are some additional fine-motor activities for Emma:
#
# *   **Sensory Bins:** Fill a bin with rice, beans, sand, or water beads and provide scoops, cups, and small toys for her to explore. This helps with grasping, pouring, and scooping.
# *   **Play with Water:** Activities like transferring water between containers with sponges or droppers, or playing with bath toys that squirt water, can be very engaging and beneficial for fine motor control.
# *   **Stickers:** Peeling and sticking stickers onto paper or designated spots can help develop pincer grasp and hand-eye coordination. Start with larger stickers and move to smaller ones as she progresses.
# *   **Crumpling Paper:** Give Emma newspaper or tissue paper to crumple into balls. This is a great way to build hand strength.
# *   **Using Tongs:** Provide child-safe tongs or tweezers for her to pick up small objects like pom-poms or cotton balls and transfer them to another container.
# *   **Simple Lacing Cards:** You can buy pre-made lacing cards or make your own by punching holes in sturdy cardboard and letting her thread yarn or pipe cleaners through.
# *   **Pincer Grasp Practice:** Offer small, safe items like Cheerios or puffs for her to pick up and eat, or to place into a bottle or container.
#
# Remember to always supervise Emma during these activities and adapt them to her current abilities and interests.
# Warning: there are non-text parts in the response: ['function_call'], returning concatenated text result from text parts. Check the full candidates.content.parts accessor to get the full model response.
# Warning: there are non-text parts in the response: ['function_call'], returning concatenated text result from text parts. Check the full candidates.content.parts accessor to get the full model response.
# gemini_researcher > For Emma, 3 years old with Down syndrome, here are some more fine-motor activities to support her development:
#
# *   **Manipulating Fasteners:** Introduce activity boards or old clothes with large buttons, zippers, and velcro closures for her to practice opening and closing. This helps with dexterity and preparing for self-dressing.
# *   **Simple Snipping with Child-Safe Scissors:** With supervision, provide blunt-nosed child scissors and strips of paper for her to practice making snips. This builds hand strength and coordination.
# *   **Inserting Objects into Slots:** Offer a piggy bank with coins (large, safe ones) or a container with a slit for her to push craft sticks or cards through. This refines precision and hand-eye coordination.
# *   **Peeling and Separating:** Encourage her to peel easy-to-manage items like a banana (after you start it for her) or pull apart orange segments. This uses both hands and develops finger strength.
# *   **Small Construction Toys:** Beyond large blocks, introduce slightly more complex construction toys like larger LEGO Duplo bricks that require a bit more force and precision to connect and disconnect.
# *   **Sticking with Glue Sticks:** Provide paper and safe glue sticks for her to apply glue to shapes or paper pieces and stick them down, which helps with grasp and bilateral coordination.
# gpt_researcher > Here are some fine motor activities for Emma, as part of her overall occupational development:
#
# *   **Puzzles and Building Blocks:** Provide her with puzzles that have large, easy-to-grasp pieces, and building blocks of various sizes to encourage manipulation, stacking, and construction. This helps with hand-eye coordination and spatial reasoning.
# *   **Simple Art Supplies:** Introduce her to crayons, chunky markers, or finger paints to encourage scribbling, drawing, and creative expression. These activities strengthen hand muscles and refine grip.
# *   **Coloring and Threading Beads:** Encourage coloring within lines (even if they're broad lines initially) and provide large beads with thick strings for threading. This helps with precision, dexterity, and bilateral coordination.
# *   **Everyday Manipulation Tasks:** Involve her in simple tasks like opening and closing containers, zipping large zippers, or buttoning large buttons. These functional activities improve practical fine motor skills.
# claude_researcher > Here are some fine-motor activities from the therapy guidance:
#
# *   Work with an occupational therapist on hand-eye coordination.
# *   Practice activities like puzzles, stacking blocks, and using child-safe utensils.
# *   Use playdough and drawing tools to develop hand strength and dexterity.
# *   Create a supportive environment that allows Emma to practice independent skills.
# aggregator_agent > Here are some additional fine-motor activities for Emma:
#
# *   **Sensory Bins:** Filling a bin with materials like rice, beans, or sand, and providing scoops and cups, can help with grasping, pouring, and scooping.
# *   **Water Play:** Activities such as transferring water between containers using sponges or droppers can be very engaging and beneficial for fine motor control.
# *   **Stickers:** Peeling and sticking stickers helps develop the pincer grasp and hand-eye coordination. Start with larger stickers and progress to smaller ones.
# *   **Crumpling Paper:** This activity helps build hand strength.
# *   **Using Tongs or Tweezers:** Child-safe tongs can be used to pick up small objects and transfer them to another container.
# *   **Simple Lacing Cards:** These help develop dexterity and hand-eye coordination.
# *   **Pincer Grasp Practice:** Offering small, safe finger foods for her to pick up and eat, or to place into a container, is excellent practice.
# *   **Manipulating Fasteners:** Activity boards or old clothes with large buttons, zippers, and velcro closures help with dexterity and self-dressing skills.
# *   **Child-Safe Scissors:** With supervision, practicing snipping with blunt-nosed scissors builds hand strength and coordination.
# *   **Inserting Objects into Slots:** Pushing craft sticks or coins into a piggy bank or container refines precision and hand-eye coordination.
# *   **Peeling and Separating:** Encouraging her to peel a banana or pull apart orange segments uses both hands and develops finger strength.
# *   **Small Construction Toys:** Toys like LEGO Duplo bricks require more force and precision to connect and disconnect, aiding development.
# *   **Using Glue Sticks:** Applying glue to shapes and sticking them down helps with grasp and bilateral coordination.
# *   **Puzzles and Building Blocks:** Puzzles with large pieces and blocks of various sizes encourage manipulation, stacking, and construction.
# *   **Simple Art Supplies:** Crayons, chunky markers, or finger paints encourage scribbling and drawing, strengthening hand muscles.
# *   **Coloring and Threading Beads:** Coloring within lines and threading large beads helps with precision, dexterity, and bilateral coordination.
# *   **Everyday Manipulation Tasks:** Involving her in opening containers, zipping zippers, or buttoning buttons improves practical fine motor skills.
#
# Remember to always supervise Emma during these activities and adapt them to her current abilities and interests.
# [Event(model_version='gemini-2.5-flash-lite', content=Content(
#    parts=[
#      Part(
#        text="""Here are some additional fine-motor activities for Emma:
#
#  *   **Sensory Bins:** Fill a bin with rice, beans, sand, or water beads and provide scoops, cups, and small toys for her to explore. This helps with grasping, pouring, and scooping.
#  *   **Play with Water:** Activities like transferring water between containers with sponges or droppers, or playing with bath toys that squirt water, can be very engaging and beneficial for fine motor control.
#  *   **Stickers:** Peeling and sticking stickers onto paper or designated spots can help develop pincer grasp and hand-eye coordination. Start with larger stickers and move to smaller ones as she progresses.
#  *   **Crumpling Paper:** Give Emma newspaper or tissue paper to crumple into balls. This is a great way to build hand strength.
#  *   **Using Tongs:** Provide child-safe tongs or tweezers for her to pick up small objects like pom-poms or cotton balls and transfer them to another container.
#  *   **Simple Lacing Cards:** You can buy pre-made lacing cards or make your own by punching holes in sturdy cardboard and letting her thread yarn or pipe cleaners through.
#  *   **Pincer Grasp Practice:** Offer small, safe items like Cheerios or puffs for her to pick up and eat, or to place into a bottle or container.
#
#  Remember to always supervise Emma during these activities and adapt them to her current abilities and interests."""
#      ),
#    ],
#    role='model'
#  ), grounding_metadata=None, partial=None, turn_complete=None, finish_reason=<FinishReason.STOP: 'STOP'>, error_code=None, error_message=None, interrupted=None, custom_metadata=None, usage_metadata=GenerateContentResponseUsageMetadata(
#    candidates_token_count=303,
#    prompt_token_count=4955,
#    prompt_tokens_details=[
#      ModalityTokenCount(
#        modality=<MediaModality.TEXT: 'TEXT'>,
#        token_count=4955
#      ),
#    ],
#    total_token_count=5258
#  ), live_session_resumption_update=None, input_transcription=None, output_transcription=None, avg_logprobs=None, logprobs_result=None, cache_metadata=None, citation_metadata=None, invocation_id='e-2e7c06d6-76e2-4cfd-94e0-d95f8d0d7daf', author='profile_agent', actions=EventActions(skip_summarization=None, state_delta={}, artifact_delta={}, transfer_to_agent=None, escalate=None, requested_auth_configs={}, requested_tool_confirmations={}, compaction=None, end_of_agent=None, agent_state=None, rewind_before_invocation_id=None), long_running_tool_ids=None, branch=None, id='0a975c4c-44d3-487b-8c26-07598167b881', timestamp=1764357149.315261),
#  Event(model_version='gemini-2.5-flash', content=Content(
#    parts=[
#      Part(
#        function_call=FunctionCall(
#          args={},
#          id='adk-61b86703-30b1-4ec4-8b9a-7c3d2ab7c354',
#          name='claude_child_research_tool'
#        ),
#        thought_signature=b'\n\xe5\x02\x01r\xc8\xda|\xeb\xb3t\xaa\x9c\xc4\xa7a\xdb\x93\x89b\x1f\x97\xed1\xdb-:jl\xbeCK\x83\x98\x8cCN\\\x8eHZ\x93\xed\xc1\xe2\x10O|d)\xb0\x11QRQ\xb7\xeer\x92\x18\xabi\xaf\xee\x8b\x02\xa5\xc6\xca\xd3qw\xa5\xf3>\xf8+*v\x02#\x8f2\xea\xd1\xbb\xbc\x01O\xc1\xea\xdd\xed\xc1v\xa7\x96...'
#      ),
#    ],
#    role='model'
#  ), grounding_metadata=None, partial=None, turn_complete=None, finish_reason=<FinishReason.STOP: 'STOP'>, error_code=None, error_message=None, interrupted=None, custom_metadata=None, usage_metadata=GenerateContentResponseUsageMetadata(
#    candidates_token_count=15,
#    prompt_token_count=3091,
#    prompt_tokens_details=[
#      ModalityTokenCount(
#        modality=<MediaModality.TEXT: 'TEXT'>,
#        token_count=3091
#      ),
#    ],
#    thoughts_token_count=70,
#    total_token_count=3176
#  ), live_session_resumption_update=None, input_transcription=None, output_transcription=None, avg_logprobs=None, logprobs_result=None, cache_metadata=None, citation_metadata=None, invocation_id='e-2e7c06d6-76e2-4cfd-94e0-d95f8d0d7daf', author='claude_researcher', actions=EventActions(skip_summarization=None, state_delta={}, artifact_delta={}, transfer_to_agent=None, escalate=None, requested_auth_configs={}, requested_tool_confirmations={}, compaction=None, end_of_agent=None, agent_state=None, rewind_before_invocation_id=None), long_running_tool_ids=set(), branch='parallel_research_team.claude_researcher', id='6dfecca6-686c-41f2-b5bc-118c60aa4669', timestamp=1764357152.286748),
#  Event(model_version=None, content=Content(
#    parts=[
#      Part(
#        function_response=FunctionResponse(
#          id='adk-61b86703-30b1-4ec4-8b9a-7c3d2ab7c354',
#          name='claude_child_research_tool',
#          response={
#            'claude_research': """Down Syndrome Overview for Emma:
#  Down syndrome is a genetic condition characterized by distinctive physical features and developmental challenges that affect Emma's learning, physical development, and cognitive growth, but with early intervention and supportive therapies, she can make significant developmental progress.
#
#  Recommended Therapy Guidance for Emma's Parents:
#
#  Language/Communication Therapies:
#  - Engage Emma in weekly speech therapy to support her language development
#  - Use picture cards and sign language to supplement verbal communication
#  - Read to her daily, pointing to words and encouraging her to repeat simple phrases
#  - Celebrate and reinforce every attempt at verbal and non-verbal communication
#
#  Physical/Movement Therapies:
#  - Participate in weekly physical therapy to support muscle tone and coordination
#  - Encourage activities like swimming, gentle gymnastics, and supervised playground play
#  - Focus on exercises that strengthen her core and improve balance
#  - Consider adaptive equipment to support her physical milestones
#
#  Occupational/Fine Motor Therapies:
#  - Work with an occupational therapist on hand-eye coordination
#  - Practice activities like puzzles, stacking blocks, and using child-safe utensils
#  - Use playdough and drawing tools to develop hand strength and dexterity
#  - Create a supportive environment that allows Emma to practice independent skills
#
#  Social/Emotional Therapies:
#  - Enroll Emma in inclusive playgroups
#  - Practice turn-taking and sharing through guided play
#  - Use positive reinforcement to build her confidence
#  - Work with a child psychologist experienced in developmental support
#
#  Cognitive/Learning Therapies:
#  - Implement early intervention educational programs
#  - Use visual learning tools and repetitive, structured learning activities
#  - Break down complex tasks into smaller, manageable steps
#  - Collaborate with special education professionals to create a personalized learning plan
#
#  Remember, every interaction is an opportunity for Emma's growth and development. Patience, consistency, and unconditional love are your most powerful tools.""",
#            'status': 'success'
#          }
#        )
#      ),
#    ],
#    role='user'
#  ), grounding_metadata=None, partial=None, turn_complete=None, finish_reason=None, error_code=None, error_message=None, interrupted=None, custom_metadata=None, usage_metadata=None, live_session_resumption_update=None, input_transcription=None, output_transcription=None, avg_logprobs=None, logprobs_result=None, cache_metadata=None, citation_metadata=None, invocation_id='e-2e7c06d6-76e2-4cfd-94e0-d95f8d0d7daf', author='claude_researcher', actions=EventActions(skip_summarization=None, state_delta={}, artifact_delta={}, transfer_to_agent=None, escalate=None, requested_auth_configs={}, requested_tool_confirmations={}, compaction=None, end_of_agent=None, agent_state=None, rewind_before_invocation_id=None), long_running_tool_ids=None, branch='parallel_research_team.claude_researcher', id='89c17cc8-0bba-4852-85a3-bf2904eb3f7d', timestamp=1764357163.054023),
#  Event(model_version='gemini-2.5-flash', content=Content(
#    parts=[
#      Part(
#        function_call=FunctionCall(
#          args={},
#          id='adk-d1c8b131-612f-4eb8-8115-3c3d80a0610f',
#          name='gpt_child_research_tool'
#        ),
#        thought_signature=b'\n\xc9\x04\x01r\xc8\xda|\xe9\xaaw\xa1\xfc\x07\xd0\xcb%sB\xd7\xcd\xfe\xca3\x8a\xf2\x1fuc\xees\xedm|BV\xb9\xc3S\x9b5,\x01n%\x0cRs\x10\xf14\x0b\xc1\xf7$5\r\xc3$\x1bC\x9a\x17\x13\xaa\xe9\xf0f\xa4Y\xb6:\xacENwU\xd5\n\xfa\xb3\x0e\xae\xec\xf2:9\x02\x00\xa4\x0e\xa4\x9c\xabb\xb5\xda...'
#      ),
#    ],
#    role='model'
#  ), grounding_metadata=None, partial=None, turn_complete=None, finish_reason=<FinishReason.STOP: 'STOP'>, error_code=None, error_message=None, interrupted=None, custom_metadata=None, usage_metadata=GenerateContentResponseUsageMetadata(
#    candidates_token_count=14,
#    prompt_token_count=2742,
#    prompt_tokens_details=[
#      ModalityTokenCount(
#        modality=<MediaModality.TEXT: 'TEXT'>,
#        token_count=2742
#      ),
#    ],
#    thoughts_token_count=112,
#    total_token_count=2868
#  ), live_session_resumption_update=None, input_transcription=None, output_transcription=None, avg_logprobs=None, logprobs_result=None, cache_metadata=None, citation_metadata=None, invocation_id='e-2e7c06d6-76e2-4cfd-94e0-d95f8d0d7daf', author='gpt_researcher', actions=EventActions(skip_summarization=None, state_delta={}, artifact_delta={}, transfer_to_agent=None, escalate=None, requested_auth_configs={}, requested_tool_confirmations={}, compaction=None, end_of_agent=None, agent_state=None, rewind_before_invocation_id=None), long_running_tool_ids=set(), branch='parallel_research_team.gpt_researcher', id='d61adefb-b588-4c6d-b89d-07044f419598', timestamp=1764357152.280627),
#  Event(model_version='gemini-2.5-flash', content=Content(
#    parts=[
#      Part(
#        text="""For Emma, 3 years old with Down syndrome, here are some more fine-motor activities to support her development:
#
#  *   **Manipulating Fasteners:** Introduce activity boards or old clothes with large buttons, zippers, and velcro closures for her to practice opening and closing. This helps with dexterity and preparing for self-dressing.
#  *   **Simple Snipping with Child-Safe Scissors:** With supervision, provide blunt-nosed child scissors and strips of paper for her to practice making snips. This builds hand strength and coordination.
#  *   **Inserting Objects into Slots:** Offer a piggy bank with coins (large, safe ones) or a container with a slit for her to push craft sticks or cards through. This refines precision and hand-eye coordination.
#  *   **Peeling and Separating:** Encourage her to peel easy-to-manage items like a banana (after you start it for her) or pull apart orange segments. This uses both hands and develops finger strength.
#  *   **Small Construction Toys:** Beyond large blocks, introduce slightly more complex construction toys like larger LEGO Duplo bricks that require a bit more force and precision to connect and disconnect.
#  *   **Sticking with Glue Sticks:** Provide paper and safe glue sticks for her to apply glue to shapes or paper pieces and stick them down, which helps with grasp and bilateral coordination.""",
#        thought_signature=b"\n\xeb\x1b\x01r\xc8\xda|\t\xf6\x0c\x0c\xff\xfd\xc00\xf5Y\xed\x84\xc9`\xb92\xbb\xb6\xce\xf0?\x03o\xcej'\x86.\x19\xbc\xc3\xa5|\xa7X\xbe\xc73R\\|r\xdf\x08\xf4'\x11\xb0N\xfa#\xecvP\xb6\x1e\xfc\xdb{\xcaj\xdb\xf0\x15>\xf7\xd0\xd3\x99\x99Kb\xed\xd5\xd6O~\x99}\x94\xea|\x1e\x0c9\x05\xcb\r\x84...'
#      ),
#    ],
#    role='model'
#  ), grounding_metadata=None, partial=None, turn_complete=None, finish_reason=<FinishReason.STOP: 'STOP'>, error_code=None, error_message=None, interrupted=None, custom_metadata=None, usage_metadata=GenerateContentResponseUsageMetadata(
#    candidates_token_count=277,
#    prompt_token_count=2375,
#    prompt_tokens_details=[
#      ModalityTokenCount(
#        modality=<MediaModality.TEXT: 'TEXT'>,
#        token_count=2375
#      ),
#    ],
#    thoughts_token_count=765,
#    total_token_count=3417
#  ), live_session_resumption_update=None, input_transcription=None, output_transcription=None, avg_logprobs=None, logprobs_result=None, cache_metadata=None, citation_metadata=None, invocation_id='e-2e7c06d6-76e2-4cfd-94e0-d95f8d0d7daf', author='gemini_researcher', actions=EventActions(skip_summarization=None, state_delta={'gemini_research': 'For Emma, 3 years old with Down syndrome, here are some more fine-motor activities to support her development:\n\n*   **Manipulating Fasteners:** Introduce activity boards or old clothes with large buttons, zippers, and velcro closures for her to practice opening and closing. This helps with dexterity and preparing for self-dressing.\n*   **Simple Snipping with Child-Safe Scissors:** With supervision, provide blunt-nosed child scissors and strips of paper for her to practice making snips. This builds hand strength and coordination.\n*   **Inserting Objects into Slots:** Offer a piggy bank with coins (large, safe ones) or a container with a slit for her to push craft sticks or cards through. This refines precision and hand-eye coordination.\n*   **Peeling and Separating:** Encourage her to peel easy-to-manage items like a banana (after you start it for her) or pull apart orange segments. This uses both hands and develops finger strength.\n*   **Small Construction Toys:** Beyond large blocks, introduce slightly more complex construction toys like larger LEGO Duplo bricks that require a bit more force and precision to connect and disconnect.\n*   **Sticking with Glue Sticks:** Provide paper and safe glue sticks for her to apply glue to shapes or paper pieces and stick them down, which helps with grasp and bilateral coordination.'}, artifact_delta={}, transfer_to_agent=None, escalate=None, requested_auth_configs={}, requested_tool_confirmations={}, compaction=None, end_of_agent=None, agent_state=None, rewind_before_invocation_id=None), long_running_tool_ids=None, branch='parallel_research_team.gemini_researcher', id='d6281954-a265-4947-b5d4-58ddebbcb7f1', timestamp=1764357152.272009),
#  Event(model_version=None, content=Content(
#    parts=[
#      Part(
#        function_response=FunctionResponse(
#          id='adk-d1c8b131-612f-4eb8-8115-3c3d80a0610f',
#          name='gpt_child_research_tool',
#          response={
#            'gpt_research': """1. Down syndrome is a genetic condition that affects physical and cognitive development, and at 3 years old, Emma may face challenges in communication, mobility, and social interaction, but she can thrive with appropriate support and intervention.
#
#  2. **Advice for Supporting Emma's Development:**
#
#     - **Language/Communication:**
#       - Engage Emma in regular storytime with interactive books to enhance her vocabulary; encourage her to express her thoughts and feelings through pictures or simple words, and use sign language or visual aids to facilitate understanding.
#
#     - **Physical/Movement:**
#       - Incorporate fun physical activities like obstacle courses or dancing to improve her gross motor skills, and consider enrolling her in a pediatric physiotherapy program that focuses on balance, coordination, and strength exercises.
#
#     - **Occupational/Fine Motor:**
#       - Provide her with toys that encourage manipulation, such as puzzles, building blocks, or simple art supplies to enhance her fine motor skills; encourage activities like coloring or threading beads to promote hand-eye coordination.
#
#     - **Social/Emotional:**
#       - Arrange playdates with peers to foster social skills and teach her to express emotions and share appropriately; model social interactions and reinforce positive behaviors with praise to help her develop emotional regulation.
#
#     - **Cognitive/Learning:**
#       - Use everyday routines to encourage learning opportunities, such as counting during snack time, sorting toys by color and size, and engaging her in simple problem-solving games to build cognitive skills; consider enrolling her in a preschool program that supports children with special needs for structured learning and social experiences.""",
#            'status': 'success'
#          }
#        )
#      ),
#    ],
#    role='user'
#  ), grounding_metadata=None, partial=None, turn_complete=None, finish_reason=None, error_code=None, error_message=None, interrupted=None, custom_metadata=None, usage_metadata=None, live_session_resumption_update=None, input_transcription=None, output_transcription=None, avg_logprobs=None, logprobs_result=None, cache_metadata=None, citation_metadata=None, invocation_id='e-2e7c06d6-76e2-4cfd-94e0-d95f8d0d7daf', author='gpt_researcher', actions=EventActions(skip_summarization=None, state_delta={}, artifact_delta={}, transfer_to_agent=None, escalate=None, requested_auth_configs={}, requested_tool_confirmations={}, compaction=None, end_of_agent=None, agent_state=None, rewind_before_invocation_id=None), long_running_tool_ids=None, branch='parallel_research_team.gpt_researcher', id='59333802-b5de-4abf-9b83-c1e1a18ea891', timestamp=1764357169.723868),
#  Event(model_version='gemini-2.5-flash', content=Content(
#    parts=[
#      Part(
#        text="""Here are some fine motor activities for Emma, as part of her overall occupational development:
#
#  *   **Puzzles and Building Blocks:** Provide her with puzzles that have large, easy-to-grasp pieces, and building blocks of various sizes to encourage manipulation, stacking, and construction. This helps with hand-eye coordination and spatial reasoning.
#  *   **Simple Art Supplies:** Introduce her to crayons, chunky markers, or finger paints to encourage scribbling, drawing, and creative expression. These activities strengthen hand muscles and refine grip.
#  *   **Coloring and Threading Beads:** Encourage coloring within lines (even if they're broad lines initially) and provide large beads with thick strings for threading. This helps with precision, dexterity, and bilateral coordination.
#  *   **Everyday Manipulation Tasks:** Involve her in simple tasks like opening and closing containers, zipping large zippers, or buttoning large buttons. These functional activities improve practical fine motor skills."""
#      ),
#    ],
#    role='model'
#  ), grounding_metadata=None, partial=None, turn_complete=None, finish_reason=<FinishReason.STOP: 'STOP'>, error_code=None, error_message=None, interrupted=None, custom_metadata=None, usage_metadata=GenerateContentResponseUsageMetadata(
#    candidates_token_count=194,
#    prompt_token_count=3121,
#    prompt_tokens_details=[
#      ModalityTokenCount(
#        modality=<MediaModality.TEXT: 'TEXT'>,
#        token_count=3121
#      ),
#    ],
#    total_token_count=3315
#  ), live_session_resumption_update=None, input_transcription=None, output_transcription=None, avg_logprobs=None, logprobs_result=None, cache_metadata=None, citation_metadata=None, invocation_id='e-2e7c06d6-76e2-4cfd-94e0-d95f8d0d7daf', author='gpt_researcher', actions=EventActions(skip_summarization=None, state_delta={'gpt_research': "Here are some fine motor activities for Emma, as part of her overall occupational development:\n\n*   **Puzzles and Building Blocks:** Provide her with puzzles that have large, easy-to-grasp pieces, and building blocks of various sizes to encourage manipulation, stacking, and construction. This helps with hand-eye coordination and spatial reasoning.\n*   **Simple Art Supplies:** Introduce her to crayons, chunky markers, or finger paints to encourage scribbling, drawing, and creative expression. These activities strengthen hand muscles and refine grip.\n*   **Coloring and Threading Beads:** Encourage coloring within lines (even if they're broad lines initially) and provide large beads with thick strings for threading. This helps with precision, dexterity, and bilateral coordination.\n*   **Everyday Manipulation Tasks:** Involve her in simple tasks like opening and closing containers, zipping large zippers, or buttoning large buttons. These functional activities improve practical fine motor skills."}, artifact_delta={}, transfer_to_agent=None, escalate=None, requested_auth_configs={}, requested_tool_confirmations={}, compaction=None, end_of_agent=None, agent_state=None, rewind_before_invocation_id=None), long_running_tool_ids=None, branch='parallel_research_team.gpt_researcher', id='3351b960-1824-43be-9840-edf677c155fb', timestamp=1764357169.747562),
#  Event(model_version='gemini-2.5-flash', content=Content(
#    parts=[
#      Part(
#        text="""Here are some fine-motor activities from the therapy guidance:
#
#  *   Work with an occupational therapist on hand-eye coordination.
#  *   Practice activities like puzzles, stacking blocks, and using child-safe utensils.
#  *   Use playdough and drawing tools to develop hand strength and dexterity.
#  *   Create a supportive environment that allows Emma to practice independent skills.""",
#        thought_signature=b'\n\x93\x03\x01r\xc8\xda|\xbf\xac\x94^l\x8fGW\xa5\xb1p&\xd5L+\x98\x9a\xc5\xc1%\xe4G\xd4<\xdd{\xe4h\x86\xce\xab\n\x04*t\x1b\x94ou\x10\xf5i"\x98\xa79\t\x06I\xa4\xa0y\xb3\xc7"U\xb53"j;\xf5\x02\xa7\xbc\xec\xb9(\xeb8\xb5"\xca#\xf3\x1a\xf6\nd\x84p\x17\xcf\xcf\x92\xbenA\xde...'
#      ),
#    ],
#    role='model'
#  ), grounding_metadata=None, partial=None, turn_complete=None, finish_reason=<FinishReason.STOP: 'STOP'>, error_code=None, error_message=None, interrupted=None, custom_metadata=None, usage_metadata=GenerateContentResponseUsageMetadata(
#    candidates_token_count=75,
#    prompt_token_count=3536,
#    prompt_tokens_details=[
#      ModalityTokenCount(
#        modality=<MediaModality.TEXT: 'TEXT'>,
#        token_count=3536
#      ),
#    ],
#    thoughts_token_count=79,
#    total_token_count=3690
#  ), live_session_resumption_update=None, input_transcription=None, output_transcription=None, avg_logprobs=None, logprobs_result=None, cache_metadata=None, citation_metadata=None, invocation_id='e-2e7c06d6-76e2-4cfd-94e0-d95f8d0d7daf', author='claude_researcher', actions=EventActions(skip_summarization=None, state_delta={'claude_research': 'Here are some fine-motor activities from the therapy guidance:\n\n*   Work with an occupational therapist on hand-eye coordination.\n*   Practice activities like puzzles, stacking blocks, and using child-safe utensils.\n*   Use playdough and drawing tools to develop hand strength and dexterity.\n*   Create a supportive environment that allows Emma to practice independent skills.'}, artifact_delta={}, transfer_to_agent=None, escalate=None, requested_auth_configs={}, requested_tool_confirmations={}, compaction=None, end_of_agent=None, agent_state=None, rewind_before_invocation_id=None), long_running_tool_ids=None, branch='parallel_research_team.claude_researcher', id='60529860-aa1a-404a-ac05-f096bc900a34', timestamp=1764357163.090413),
#  Event(model_version='gemini-2.5-flash-lite', content=Content(
#    parts=[
#      Part(
#        text="""Here are some additional fine-motor activities for Emma:
#
#  *   **Sensory Bins:** Filling a bin with materials like rice, beans, or sand, and providing scoops and cups, can help with grasping, pouring, and scooping.
#  *   **Water Play:** Activities such as transferring water between containers using sponges or droppers can be very engaging and beneficial for fine motor control.
#  *   **Stickers:** Peeling and sticking stickers helps develop the pincer grasp and hand-eye coordination. Start with larger stickers and progress to smaller ones.
#  *   **Crumpling Paper:** This activity helps build hand strength.
#  *   **Using Tongs or Tweezers:** Child-safe tongs can be used to pick up small objects and transfer them to another container.
#  *   **Simple Lacing Cards:** These help develop dexterity and hand-eye coordination.
#  *   **Pincer Grasp Practice:** Offering small, safe finger foods for her to pick up and eat, or to place into a container, is excellent practice.
#  *   **Manipulating Fasteners:** Activity boards or old clothes with large buttons, zippers, and velcro closures help with dexterity and self-dressing skills.
#  *   **Child-Safe Scissors:** With supervision, practicing snipping with blunt-nosed scissors builds hand strength and coordination.
#  *   **Inserting Objects into Slots:** Pushing craft sticks or coins into a piggy bank or container refines precision and hand-eye coordination.
#  *   **Peeling and Separating:** Encouraging her to peel a banana or pull apart orange segments uses both hands and develops finger strength.
#  *   **Small Construction Toys:** Toys like LEGO Duplo bricks require more force and precision to connect and disconnect, aiding development.
#  *   **Using Glue Sticks:** Applying glue to shapes and sticking them down helps with grasp and bilateral coordination.
#  *   **Puzzles and Building Blocks:** Puzzles with large pieces and blocks of various sizes encourage manipulation, stacking, and construction.
#  *   **Simple Art Supplies:** Crayons, chunky markers, or finger paints encourage scribbling and drawing, strengthening hand muscles.
#  *   **Coloring and Threading Beads:** Coloring within lines and threading large beads helps with precision, dexterity, and bilateral coordination.
#  *   **Everyday Manipulation Tasks:** Involving her in opening containers, zipping zippers, or buttoning buttons improves practical fine motor skills.
#
#  Remember to always supervise Emma during these activities and adapt them to her current abilities and interests."""
#      ),
#    ],
#    role='model'
#  ), grounding_metadata=None, partial=None, turn_complete=None, finish_reason=<FinishReason.STOP: 'STOP'>, error_code=None, error_message=None, interrupted=None, custom_metadata=None, usage_metadata=GenerateContentResponseUsageMetadata(
#    candidates_token_count=514,
#    prompt_token_count=7458,
#    prompt_tokens_details=[
#      ModalityTokenCount(
#        modality=<MediaModality.TEXT: 'TEXT'>,
#        token_count=7458
#      ),
#    ],
#    total_token_count=7972
#  ), live_session_resumption_update=None, input_transcription=None, output_transcription=None, avg_logprobs=None, logprobs_result=None, cache_metadata=None, citation_metadata=None, invocation_id='e-2e7c06d6-76e2-4cfd-94e0-d95f8d0d7daf', author='aggregator_agent', actions=EventActions(skip_summarization=None, state_delta={'final_summary': 'Here are some additional fine-motor activities for Emma:\n\n*   **Sensory Bins:** Filling a bin with materials like rice, beans, or sand, and providing scoops and cups, can help with grasping, pouring, and scooping.\n*   **Water Play:** Activities such as transferring water between containers using sponges or droppers can be very engaging and beneficial for fine motor control.\n*   **Stickers:** Peeling and sticking stickers helps develop the pincer grasp and hand-eye coordination. Start with larger stickers and progress to smaller ones.\n*   **Crumpling Paper:** This activity helps build hand strength.\n*   **Using Tongs or Tweezers:** Child-safe tongs can be used to pick up small objects and transfer them to another container.\n*   **Simple Lacing Cards:** These help develop dexterity and hand-eye coordination.\n*   **Pincer Grasp Practice:** Offering small, safe finger foods for her to pick up and eat, or to place into a container, is excellent practice.\n*   **Manipulating Fasteners:** Activity boards or old clothes with large buttons, zippers, and velcro closures help with dexterity and self-dressing skills.\n*   **Child-Safe Scissors:** With supervision, practicing snipping with blunt-nosed scissors builds hand strength and coordination.\n*   **Inserting Objects into Slots:** Pushing craft sticks or coins into a piggy bank or container refines precision and hand-eye coordination.\n*   **Peeling and Separating:** Encouraging her to peel a banana or pull apart orange segments uses both hands and develops finger strength.\n*   **Small Construction Toys:** Toys like LEGO Duplo bricks require more force and precision to connect and disconnect, aiding development.\n*   **Using Glue Sticks:** Applying glue to shapes and sticking them down helps with grasp and bilateral coordination.\n*   **Puzzles and Building Blocks:** Puzzles with large pieces and blocks of various sizes encourage manipulation, stacking, and construction.\n*   **Simple Art Supplies:** Crayons, chunky markers, or finger paints encourage scribbling and drawing, strengthening hand muscles.\n*   **Coloring and Threading Beads:** Coloring within lines and threading large beads helps with precision, dexterity, and bilateral coordination.\n*   **Everyday Manipulation Tasks:** Involving her in opening containers, zipping zippers, or buttoning buttons improves practical fine motor skills.\n\nRemember to always supervise Emma during these activities and adapt them to her current abilities and interests.'}, artifact_delta={}, transfer_to_agent=None, escalate=None, requested_auth_configs={}, requested_tool_confirmations={}, compaction=None, end_of_agent=None, agent_state=None, rewind_before_invocation_id=None), long_running_tool_ids=None, branch=None, id='72da3978-0e55-4e71-a9f6-f9cbe393f6cf', timestamp=1764357171.972238)]

# %% [markdown]
# [Profile Agent] → stores child:name, age, diagnosis
#
# [Parallel Research Team]
#    - ├── Gemini researcher → Gemini_child_tool → personalized research
#    - ├── GPT researcher    → GPT_child_tool    → personalized research
#    - └── Claude researcher → Claude_child_tool → personalized research
#
# [Aggregator Agent] → merges 3 sources using child profile

# %% [markdown]
# ### DB Inspection

# %%
import sqlite3

def print_events_schema(db_path="genex_sessions.db"):
    conn = sqlite3.connect(db_path)
    cursor = conn.cursor()

    print("🔍 EVENTS TABLE SCHEMA:")
    rows = cursor.execute("PRAGMA table_info(events);")
    for r in rows.fetchall():
        print(r)

    conn.close()

print_events_schema()
# Out:
# 🔍 EVENTS TABLE SCHEMA:
# (0, 'id', 'VARCHAR(128)', 1, None, 1)
# (1, 'app_name', 'VARCHAR(128)', 1, None, 2)
# (2, 'user_id', 'VARCHAR(128)', 1, None, 3)
# (3, 'session_id', 'VARCHAR(128)', 1, None, 4)
# (4, 'invocation_id', 'VARCHAR(256)', 1, None, 0)
# (5, 'author', 'VARCHAR(256)', 1, None, 0)
# (6, 'actions', 'BLOB', 1, None, 0)
# (7, 'long_running_tool_ids_json', 'TEXT', 0, None, 0)
# (8, 'branch', 'VARCHAR(256)', 0, None, 0)
# (9, 'timestamp', 'DATETIME', 1, None, 0)
# (10, 'content', 'TEXT', 0, None, 0)
# (11, 'grounding_metadata', 'TEXT', 0, None, 0)
# (12, 'custom_metadata', 'TEXT', 0, None, 0)
# (13, 'usage_metadata', 'TEXT', 0, None, 0)
# (14, 'citation_metadata', 'TEXT', 0, None, 0)
# (15, 'partial', 'BOOLEAN', 0, None, 0)
# (16, 'turn_complete', 'BOOLEAN', 0, None, 0)
# (17, 'error_code', 'VARCHAR(256)', 0, None, 0)
# (18, 'error_message', 'VARCHAR(1024)', 0, None, 0)
# (19, 'interrupted', 'BOOLEAN', 0, None, 0)
